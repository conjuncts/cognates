# %%
import pandas as pd

# %%
df = pd.read_csv('ety_data.csv')

# %%
# drop Unnamed: 0
# df = df.drop('Unnamed: 0', axis=1)
# df.to_csv('ety_data.csv', index=False)

# %%
# parse "templates" using ast.literal_eval
import ast
df['templates'] = df['templates'].apply(ast.literal_eval)

# %%
df.to_pickle('ety_data.pkl')
